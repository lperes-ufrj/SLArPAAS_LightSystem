# %% [markdown]
# >#### Wed Jul 3, 2024
# -------------------------------------------
# > - Using the setup with the power supply Keithley 2450.
# > - Measuring the response with nEXO Board shipped from UCSD.
# > - PreAmp Board with $-5V$ and $+5V$.
# > - Bias Voltage of $-56V$.
# --------------------------------------------------------

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = 'FirstSiPM_ScopeData/noah-56v-3p9-mua.csv'
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**9  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'nano seconds (ns)')
plt.grid()
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper right', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# ------------------------------------------
# --------------------------------------------------------

# %%
csv_file = 'FirstSiPM_ScopeData/noah-56v-3p9-mua1.csv'
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**9  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'nano seconds (ns)')
plt.grid()
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper right', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()

# %%
csv_file = 'FirstSiPM_ScopeData/noah-56v-3p9-mua2.csv'
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**9  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'nano seconds (ns)')
plt.grid()
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper right', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()
