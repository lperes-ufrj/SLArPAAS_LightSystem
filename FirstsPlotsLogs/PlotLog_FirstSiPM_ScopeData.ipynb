# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
csv_file = 'FirstSiPM_ScopeData/scope_sipm-test3.csv'
# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file)
data.head()
# Out:
#    second     Volt
# 0   -2.50 -0.06030
# 1   -2.45 -0.06030
# 2   -2.40 -0.06030
# 3   -2.35 -0.06030
# 4   -2.30 -0.05307

# %%
# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y = data.iloc[:, 1]  # the second column is Volts

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y, marker='.', linestyle='--')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')

plt.show()

# %%
#### May 31 2024 ####

# %%
csv_file = 'FirstSiPM_ScopeData/scope-test-1mohm.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()
# Out:
#      second      Volt    Volt.1
# 0 -2.514844 -2.601382 -0.061809
# 1 -2.512344 -2.602638 -0.046420
# 2 -2.509844 -2.681784 -0.061181
# 3 -2.507344 -2.681784 -0.046420
# 4 -2.504844 -2.662940 -0.066520

# %%
# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
csv_file = 'FirstSiPM_ScopeData/scope-test-40mohm1.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
###Mon Jun 3 2024 #####

# %%
csv_file = 'FirstSiPM_ScopeData/scope_sipm-erise1.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
plt.scatter(y1[y1>1.5],y2[y1>1.5],s=0.8, alpha=0.7)
plt.show()

# %%
csv_file = 'FirstSiPM_ScopeData/scope_sipm-eris-al.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
### Tue Jue 4 2024 ####

# %%
csv_file = 'FirstSiPM_ScopeData/scope_0-preamp-v02.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
csv_file = 'FirstSiPM_ScopeData/scope_0-preamp-v01.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
csv_file = 'FirstSiPM_ScopeData/scope20Mohm-pamp1.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
csv_file = 'FirstSiPM_ScopeData/scope20Mohm-pamp2.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel('seconds (s)')
plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
#Bias connected directed in the SiPM PCB
csv_file = 'FirstSiPM_ScopeData/scope1Mohm-pamp3.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='.', linestyle='--', label='WaveGenerator')
plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
import scipy.optimize as opt
import numpy as np

def model_expodecay(t, A, K, C):
    return A * np.exp(-K * t) + C

opt_parms, parm_cov = opt.curve_fit(model_expodecay, x[x>100], y2[x>100], p0=[1.,0.01, 1.2])
A, K, C = opt_parms

# %%
print(1./K) ## ~15 mu s characteristic of which process, what is happing here???
# Out:
# 14.755436209163008

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x[x>100], y2[x>100], marker='.', linestyle='--',  label='SiPM')
plt.plot(x[x>100],model_expodecay(x[x>100],A,K,C))
plt.plot()
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

### Ok, the fit is good enough

# %%
### Wed Jun 5 ###

### Individually pulse-noise from the preamp??

#Bias connected directed in the SiPM PCB
csv_file = 'FirstSiPM_ScopeData/only-pamp-nobias-si1.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='', linestyle='-', label='WaveGenerator')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds

y = np.array(data.iloc[:, 1])[1:]
y1 = np.fft.fft(y[x[1:]>0])  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

freq = np.fft.fftfreq(y1.shape[-1])

# Plot the data
plt.figure(figsize=(10, 6))
plt.stem(freq, np.abs(y1), label='WaveGenerator',markerfmt=" ", basefmt="-b")
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.xlabel('Freq (MHz)')
plt.ylabel('FFT Amplitude |Y(freq)|')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Vpp Amplitude WaveGenerator: {round(np.abs(y1.max()-y1.min()),2)} V', ncols=2 )
plt.show()

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x[1:][x>0], np.fft.ifft(y1), linestyle='-', label='WaveGenerator')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()
# Out:
# /usr/lib/python3/dist-packages/matplotlib/cbook/__init__.py:1369: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
### Wed Jun 5 ###

### Noise from the Pre Amp ?????

#Bias connected directed in the SiPM PCB
csv_file = 'FirstSiPM_ScopeData/only-pamp-nobias-si3.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='', linestyle='-', label='WaveGenerator')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {y2.max()-y2.min()} V\nMax. Vpp Amplitude WaveGenerator: {(y1.max()-y1.min())/2} V', ncols=2 )
plt.show()

# %%
## Fri Jun 7 ##
#PreAmp is in a case, we connect the bias fromthe power supply in the preamp using its filter and then goes to the SiPM PCB
csv_file = 'FirstSiPM_ScopeData/pampcase-fbias-noled.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y1.max()-y1.min(),5)} V\n Dark Light?', ncols=2)
plt.show()

# %%
## Fri Jun 7 ##
#PreAmp is in a case, we connect the bias from the power supply in the SiPM PCB directly
csv_file = 'FirstSiPM_ScopeData/pampcase-dbias-nole1.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y1.max()-y1.min(),5)} V ', ncols=2)
plt.show()

# %%
## Fri Jun 7 ##
#PreAmp is in a case, we connect the bias from the power supply in the SiPM PCB directly
csv_file = 'FirstSiPM_ScopeData/pampcase-dbias-nole2.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y1.max()-y1.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# >#### Mon Jun 10, 2024
# -------------------------------------------
# > - Looking for Dark Light high signal (~200mV)
# > - Using a KEITHLEY 2400 Power Supply for the SiPM Bias that goes in the PreAmp Board (Using the PreAmp Filter).
# > - The LED is off.
# > - Supply for the PreAmp Board is at +6V and -6V.
# > - Information from the Power Supply: $V_{src}$ = -55V, Cmpl = 25 $\mu$ A.

# %% [markdown]
# #### First Plot with a 55Volts Bias from the "new" Power Supply

# %%
csv_file = 'FirstSiPM_ScopeData/55vbi-2400-noled-wf2.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x = data.iloc[:, 0]*10**6  # the first column is seconds
y1 = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x, y1, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y1.max()-y1.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# #### Next Plot is the same configuration but now with 60V Bias in the Power Supply ($V_{src}$ = -60V)

# %%
csv_file = 'FirstSiPM_ScopeData/60vbi-2400-noled-wfi.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_kei = data.iloc[:, 0]*10**6  # the first column is seconds
y_kei = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_kei, y_kei, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y_kei.max()-y_kei.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# #### Using the BK Precision 9130 Power Supply with the same $V\approx -60V$, we get a similar pulse

# %%
csv_file = 'FirstSiPM_ScopeData/bk60bias-noled.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**6  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# #### Plotting together:

# %%
# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='BK PRECISION 9130')
plt.plot(x_kei, y_kei, marker='', linestyle='-', label='KEITHLEY 2400')
plt.hlines(0.034475,x_kei.min(),x_kei.max(), label = 'KEITHLEY Trigger ', ls= '--',color='orange')
plt.hlines(0.0312,x_kei.min(),x_kei.max(), label = 'BK Trigger ', ls= '--', color = 'blue')

#plt.hlines(0.035875,x_kei.min(),x_kei.max(), label = 'KEITHLEY Offset', ls= '-',color='orange')
#plt.hlines(0.023825,x_kei.min(),x_kei.max(), label = 'BK Offset', ls= '-', color = 'blue')
plt.grid(ls='--')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'micro seconds ($\mu$s)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = r'$V_{Bias} \approx -60V$', ncols=2)
plt.show()

# %% [markdown]
# #### Power Supply seems to not interfer in the dark pulse (?)

# %% [markdown]
# >#### Tue Jun 11, 2024
# -------------------------------------------
# > - If the current limit of the Vpos in the PreAmplifier board is set too small, the big bypass capacitor to reduce noise could not be charged (?) - Best hipothesis
# > - We still do not see any signal with SiPM for the PreAmps chips replaced.
# > - Debugging the PreAmp Board.
# > - Problems with the second PreAmp Chip.
# > - Measurements of the PreAmp Board without the Chip.
# > - PreAmp sometimes starts badly??
#
# > - Conclusion from the above:
# > - The Power Supply BK Precision must measure the same current in both channels (+6V) and (-6V) to work well.
# > - You should plug the plus and minos in the PreAmp at the same time.
# > - If the negative starts at first, maybe the PreAmp does not turn on.
#
# > - Main lesson: The same current in the power supply for the V+ and V-  of the pre amp board, otherwise it will not start correctly.
# > - With the right start operating "protocol" we see a large signal (~$200mV$) probably form the SiPM, but with a highly oscillating tail.
# > - This last effect could be due to the lack of the capacitor in the PreAmp board, With the faster preamps chips we see this oscillating signal.
# > -  Testing the PreAmp Board with a $10\;pF$ capacitor in the place unpopulated.
# > - Reduce the bandwidth of oscillation, but as the capacitor goes larger the amplitude is also reduced.
#
# > - Test the current stage of the PreAmp board with a signal generator.
#
# --------------------------------------------------------

# %% [markdown]
# >#### Thu Jun 13, 2024
# -------------------------------------------
# > - Adding a $15pF$ capacitor on the PreAmp Board.
# <div>
# <img src="image.png" width="300"/>
# </div>
#
# > - Measuring the current with a KEITHLEY 2400 Power Supply, $-10.8 \mu A$, with the SiPM case revested of aluminum foil, and the SiPM bias at $-60V$.
# > - We can see a pulse of $\approx 40 mV$ of amplitude, with no LED connected.
# > - Connecting the Bias first in the PreAmp Board to use its filter.

# %%
csv_file = 'FirstSiPM_ScopeData/newpreamps-noled-60v.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**9  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'nano seconds (ns)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# > - In the next plot, the bias is direct connected at the SiPM board.
# > - Then, we can observe a larger pulse ($\approx 65 mV$), but with no considerable change in the oscillating part.
# > - Measuring the current with a KEITHLEY 2400 Power Supply, $-17.4 \mu A$, with the SiPM case revested of aluminum foil, and the SiPM bias at $-60V$.

# %%
csv_file = 'FirstSiPM_ScopeData/newpreampsnoled-60nf.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**9  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'nano seconds (ns)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()

# %% [markdown]
# >#### Wed Jun 19, 2024
# -------------------------------------------
# > - Testing the setup with the new power supply Keithley 2450
# > - In the graph below, the bias is at $-55V$, and connected directly in the SiPM with no use of the filter in the PreAmp board.
# > - The current measured was $-2.3\mu A$.
# --------------------------------------------------------

# %%
csv_file = 'FirstSiPM_ScopeData/2450-55v-nofi-2-3mua.csv'

# Read the CSV file into a pandas DataFrame
data = pd.read_csv(csv_file,skiprows=1)
data.head()

# Extract the columns
x_bk = data.iloc[:, 0]*10**9  # the first column is seconds
y_bk = data.iloc[:, 1]  # the second column is Volts (WaveGenerator)
#y2 = data.iloc[:, 2]  # the second column is Volts (SiPM)

# Plot the data
plt.figure(figsize=(10, 6))
plt.plot(x_bk, y_bk, marker='', linestyle='-', label='SiPM')
#plt.plot(x, y2, marker='.', linestyle='--',  label='SiPM')
plt.ylabel('Volts (V)')
plt.xlabel(r'nano seconds (ns)')
#plt.yscale('log')
plt.title('Plot of CSV Data Oscilloscope')
plt.legend(loc='upper left', title = f'Max. Amplitude Signal SiPM: {round(y_bk.max()-y_bk.min(),5)} V', ncols=2)
plt.show()
